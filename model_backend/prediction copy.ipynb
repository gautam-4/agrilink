# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from lazypredict.Supervised import LazyRegressor
from sklearn.utils import all_estimators
from sklearn.base import RegressorMixin
from sklearn.model_selection import learning_curve

# %%
#Loading the Dataset
Path_to_data = "climate-ds.csv"
data = pd.read_csv(Path_to_data, index_col=['Unnamed: 0'])
data.head(10)
# Out:
#       Area         Item  Year  average_rain_fall_mm_per_year  \
# 0  Albania        Maize  1990                           1485
# 1  Albania     Potatoes  1990                           1485
# 2  Albania  Rice, paddy  1990                           1485
# 3  Albania      Sorghum  1990                           1485
# 4  Albania     Soybeans  1990                           1485
# 5  Albania        Wheat  1990                           1485
# 6  Albania        Maize  1991                           1485
# 7  Albania     Potatoes  1991                           1485
# 8  Albania  Rice, paddy  1991                           1485
# 9  Albania      Sorghum  1991                           1485
#
#    pesticides_tonnes  avg_temp  hg/ha_yield
# 0             121.00     16.37        36613
# 1             121.00     16.37        66667
# 2             121.00     16.37        23333
# 3             121.00     16.37        12500
# 4             121.00     16.37         7000
# 5             121.00     16.37        30197
# 6             121.00     15.36        29068
# 7             121.00     15.36        77818
# 8             121.00     15.36        28538
# 9             121.00     15.36         6667

# %%
data = data[data['Area'] == 'India']

# %%
#Checking shape
rows, columns = data.shape
print('There are {} rows and {} columns.'.format(rows, columns))
# Out:
# There are 4048 rows and 7 columns.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4048 entries, 10502 to 14549
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Area                           4048 non-null   object
#  1   Item                           4048 non-null   object
#  2   Year                           4048 non-null   int64
#  3   average_rain_fall_mm_per_year  4048 non-null   int64
#  4   pesticides_tonnes              4048 non-null   float64
#  5   avg_temp                       4048 non-null   float64
#  6   hg/ha_yield                    4048 non-null   int64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 253.0+ KB

# %%
data.describe()
# Out:
#          Year  average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp  \
# count 4048.00                        4048.00            4048.00   4048.00
# mean  2001.43                        1083.00           48459.04     26.01
# std      7.06                           0.00           14997.35      0.91
# min   1990.00                        1083.00           14485.33     23.26
# 25%   1995.00                        1083.00           37423.00     25.46
# 50%   2001.00                        1083.00           46195.00     25.98
# 75%   2008.00                        1083.00           61257.00     26.67
# max   2013.00                        1083.00           75000.00     28.85
#
#        hg/ha_yield
# count      4048.00
# mean      80884.47
# std       95950.22
# min        6553.00
# 25%       13704.75
# 50%       28124.00
# 75%      112471.00
# max      385818.00

# %%
data.isnull().sum()
# Out:
# Area                             0
# Item                             0
# Year                             0
# average_rain_fall_mm_per_year    0
# pesticides_tonnes                0
# avg_temp                         0
# hg/ha_yield                      0
# dtype: int64

# %% [markdown]
# No Null values. Proceeding with understanding the unique values of the Item column.

# %%
data["Item"].value_counts()
# Out:
# Item
# Cassava           506
# Maize             506
# Potatoes          506
# Rice, paddy       506
# Sorghum           506
# Soybeans          506
# Sweet potatoes    506
# Wheat             506
# Name: count, dtype: int64

# %% [markdown]
# Removing the 'Year' column

# %%
data = data.drop(["Year"], axis=1)  
data.head(10)
# Out:
#         Area     Item  average_rain_fall_mm_per_year  pesticides_tonnes  \
# 10502  India  Cassava                           1083           75000.00
# 10503  India  Cassava                           1083           75000.00
# 10504  India  Cassava                           1083           75000.00
# 10505  India  Cassava                           1083           75000.00
# 10506  India  Cassava                           1083           75000.00
# 10507  India  Cassava                           1083           75000.00
# 10508  India  Cassava                           1083           75000.00
# 10509  India  Cassava                           1083           75000.00
# 10510  India  Cassava                           1083           75000.00
# 10511  India  Cassava                           1083           75000.00
#
#        avg_temp  hg/ha_yield
# 10502     25.58       205381
# 10503     26.88       205381
# 10504     25.79       205381
# 10505     24.10       205381
# 10506     25.25       205381
# 10507     25.44       205381
# 10508     25.54       205381
# 10509     26.36       205381
# 10510     26.91       205381
# 10511     25.16       205381

# %% [markdown]
# One-Hot Encoding

# %%
data = pd.get_dummies(data, columns=['Area', 'Item'])  # Convert categorical variables to dummy/indicator variables
data.head(10)
# Out:
#        average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp  \
# 10502                           1083           75000.00     25.58
# 10503                           1083           75000.00     26.88
# 10504                           1083           75000.00     25.79
# 10505                           1083           75000.00     24.10
# 10506                           1083           75000.00     25.25
# 10507                           1083           75000.00     25.44
# 10508                           1083           75000.00     25.54
# 10509                           1083           75000.00     26.36
# 10510                           1083           75000.00     26.91
# 10511                           1083           75000.00     25.16
#
#        hg/ha_yield  Area_India  Item_Cassava  Item_Maize  Item_Potatoes  \
# 10502       205381        True          True       False          False
# 10503       205381        True          True       False          False
# 10504       205381        True          True       False          False
# 10505       205381        True          True       False          False
# 10506       205381        True          True       False          False
# 10507       205381        True          True       False          False
# 10508       205381        True          True       False          False
# 10509       205381        True          True       False          False
# 10510       205381        True          True       False          False
# 10511       205381        True          True       False          False
#
#        Item_Rice, paddy  Item_Sorghum  Item_Soybeans  Item_Sweet potatoes  \
# 10502             False         False          False                False
# 10503             False         False          False                False
# 10504             False         False          False                False
# 10505             False         False          False                False
# 10506             False         False          False                False
# 10507             False         False          False                False
# 10508             False         False          False                False
# 10509             False         False          False                False
# 10510             False         False          False                False
# 10511             False         False          False                False
#
#        Item_Wheat
# 10502       False
# 10503       False
# 10504       False
# 10505       False
# 10506       False
# 10507       False
# 10508       False
# 10509       False
# 10510       False
# 10511       False

# %% [markdown]
# Feature Scaling

# %%
X = data.loc[:, data.columns != 'hg/ha_yield']  # All columns except target 'hg/ha_yield'
Y = data['hg/ha_yield']  # Target variable

# %%
X.head(10)
# Out:
#        average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp  Area_India  \
# 10502                           1083           75000.00     25.58        True
# 10503                           1083           75000.00     26.88        True
# 10504                           1083           75000.00     25.79        True
# 10505                           1083           75000.00     24.10        True
# 10506                           1083           75000.00     25.25        True
# 10507                           1083           75000.00     25.44        True
# 10508                           1083           75000.00     25.54        True
# 10509                           1083           75000.00     26.36        True
# 10510                           1083           75000.00     26.91        True
# 10511                           1083           75000.00     25.16        True
#
#        Item_Cassava  Item_Maize  Item_Potatoes  Item_Rice, paddy  \
# 10502          True       False          False             False
# 10503          True       False          False             False
# 10504          True       False          False             False
# 10505          True       False          False             False
# 10506          True       False          False             False
# 10507          True       False          False             False
# 10508          True       False          False             False
# 10509          True       False          False             False
# 10510          True       False          False             False
# 10511          True       False          False             False
#
#        Item_Sorghum  Item_Soybeans  Item_Sweet potatoes  Item_Wheat
# 10502         False          False                False       False
# 10503         False          False                False       False
# 10504         False          False                False       False
# 10505         False          False                False       False
# 10506         False          False                False       False
# 10507         False          False                False       False
# 10508         False          False                False       False
# 10509         False          False                False       False
# 10510         False          False                False       False
# 10511         False          False                False       False

# %%
Y.head(10)
# Out:
# 10502    205381
# 10503    205381
# 10504    205381
# 10505    205381
# 10506    205381
# 10507    205381
# 10508    205381
# 10509    205381
# 10510    205381
# 10511    205381
# Name: hg/ha_yield, dtype: int64

# %% [markdown]
# Normalization

# %%
x_max = X.max()
X = X.divide(x_max)
X.describe()
# Out:
#         average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp  \
# count                         4048.00            4048.00   4048.00
# unique                           1.00              23.00    239.00
# top                              1.00               1.00      0.89
# freq                          4048.00             176.00     56.00
#
#         Area_India  Item_Cassava  Item_Maize  Item_Potatoes  Item_Rice, paddy  \
# count      4048.00       4048.00     4048.00        4048.00           4048.00
# unique        1.00          2.00        2.00           2.00              2.00
# top           1.00          0.00        0.00           0.00              0.00
# freq       4048.00       3542.00     3542.00        3542.00           3542.00
#
#         Item_Sorghum  Item_Soybeans  Item_Sweet potatoes  Item_Wheat
# count        4048.00        4048.00              4048.00     4048.00
# unique          2.00           2.00                 2.00        2.00
# top             0.00           0.00                 0.00        0.00
# freq         3542.00        3542.00              3542.00     3542.00

# %%
print(X.shape)
print(Y.shape)
# Out:
# (4048, 12)
# (4048,)

# %% [markdown]
# TRAIN-TEST SPLIT

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
print(x_train.shape)  # Training features
# Out:
# (3238, 12)

# %%
print(y_train.shape)  # Training labels
# Out:
# (3238,)

# %% [markdown]
# FUNCTION TO CALCULATE THE RMSE

# %%
# Function to calculate RMSE
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %% [markdown]
# RANDOM FOREST REGRESSOR TRAINING

# %%
print("Random Forest Regressor:")
random_forest_model = RandomForestRegressor(n_estimators=100, random_state=42)
random_forest_model.fit(x_train, y_train)
y_pred_rf = random_forest_model.predict(x_test)
# Out:
# Random Forest Regressor:

# %%
final_predictions = pd.DataFrame({
    'Actual Yield': y_test,
    'OUR Prediction': y_pred_rf,
    
})

print(final_predictions.head())
# Out:
#        Actual Yield  OUR Prediction
# 11661          9591         9591.00
# 10651         79663        79663.00
# 14410         25726        25726.00
# 14024        364770       364770.00
# 13707         20238        20238.00
